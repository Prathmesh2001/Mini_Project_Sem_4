# %% [markdown]
# # This is an extension of Project_ori notebook

# %% [markdown]
# To handle missing values

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import missingno as msno
from sklearn import metrics
import pickle

df = pickle.load(open('df_corrected','rb'))
df.head()
# Out:
#    id       car_name    brand     model  \
# 0   0    Maruti Alto   Maruti      Alto
# 1   1  Hyundai Grand  Hyundai     Grand
# 2   2    Hyundai i20  Hyundai       i20
# 3   3    Maruti Alto   Maruti      Alto
# 4   4  Ford Ecosport     Ford  Ecosport
#
#                                         new_price  min_cost_price  \
# 0                                             NaN             NaN
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*        711000.0
# 2                                             NaN             NaN
# 3                                             NaN             NaN
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*       1014000.0
#
#    max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 0             NaN            9     120000  Individual    Petrol
# 1        748000.0            5      20000  Individual    Petrol
# 2             NaN           11      60000  Individual    Petrol
# 3             NaN            9      37000  Individual    Petrol
# 4       1379000.0            6      30000      Dealer    Diesel
#
#   transmission_type  mileage  engine  max_power  seats  selling_price
# 0            Manual    19.70     796      46.30      5         120000
# 1            Manual    18.90    1197      82.00      5         550000
# 2            Manual    17.00    1197      80.00      5         215000
# 3            Manual    20.92     998      67.10      5         226000
# 4            Manual    22.77    1498      98.59      5         570000

# %%
df.shape
# Out:
# (19544, 17)

# %% [markdown]
# # Check for NaN values

# %%
print("\n Missing percentage \n")
print(df.isnull().mean()*100)
# Out:
#  Missing percentage
#
# id                    0.000000
# car_name              0.000000
# brand                 0.000000
# model                 0.000000
# new_price            51.688498
# min_cost_price       51.688498
# max_cost_price       51.688498
# vehicle_age           0.000000
# km_driven             0.000000
# seller_type           0.000000
# fuel_type             0.000000
# transmission_type     0.000000
# mileage               0.000000
# engine                0.000000
# max_power             0.000000
# seats                 0.000000
# selling_price         0.000000
# dtype: float64

# %%
#bar graph to show how much data is missing and from which columns
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
#Check the correlation of all columns with selling price
corr_matrix = df.corr()
print(corr_matrix["selling_price"].sort_values(ascending=False))
# Out:
# selling_price     1.000000
# min_cost_price    0.771494
# max_power         0.750761
# max_cost_price    0.697012
# engine            0.587358
# seats             0.073442
# id                0.024660
# km_driven        -0.103680
# vehicle_age      -0.267211
# mileage          -0.289664
# Name: selling_price, dtype: float64

# %%
heat = plt.subplots(figsize = (11,8))
heat = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#this shows that all missing data of new price corresponds to missing data of max_cost and min_cost
msno.heatmap(df, cmap="RdYlGn", figsize=(10,5), fontsize=12);

# %% [markdown]
# # Using KNN Imputer to handle missing values

# %%
brand_list = df['brand'].unique()
model_list = df['model'].unique()
brands = pd.Series(brand_list)
# print("\nTotal number of brands: ",brands.shape)
# df['brand'].value_counts()

# %%
#df_knn is dataframe that we use to impute missing values
df_knn = pd.DataFrame(df)
df_knn.drop(['vehicle_age','km_driven','mileage'],axis=1,inplace=True)
#knn for missing values
import numpy as np
from sklearn.impute import KNNImputer
knn = KNNImputer(n_neighbors=3)
num = [col for col in df_knn.columns if df_knn[col].dtypes != 'O']
knn.fit(df_knn[num])
df2 = pd.DataFrame(knn.transform(df_knn[num]))
df2.head(20)
# Out:
#        0             1             2       3       4    5          6
# 0    0.0  5.160000e+05  6.883333e+05   796.0   46.30  5.0   120000.0
# 1    1.0  7.110000e+05  7.480000e+05  1197.0   82.00  5.0   550000.0
# 2    2.0  1.075667e+06  1.412333e+06  1197.0   80.00  5.0   215000.0
# 3    3.0  4.076667e+05  5.453333e+05   998.0   67.10  5.0   226000.0
# 4    4.0  1.014000e+06  1.379000e+06  1498.0   98.59  5.0   570000.0
# 5    5.0  5.160000e+05  6.940000e+05   998.0   67.10  5.0   350000.0
# 6    6.0  6.540000e+05  6.630000e+05  1197.0   78.90  5.0   315000.0
# 7    7.0  5.260000e+05  7.010000e+05   998.0   67.04  5.0   410000.0
# 8    8.0  7.700000e+05  1.302000e+06   998.0  118.35  5.0  1050000.0
# 9    9.0  7.286667e+05  1.135667e+06  1493.0  100.00  7.0   575000.0
# 10  10.0  5.313333e+05  7.363333e+05  1405.0   69.01  5.0   305000.0
# 11  11.0  1.543667e+06  2.083667e+06  1461.0  108.49  5.0  1150000.0
# 12  12.0  6.350000e+05  9.270000e+05  1197.0   85.00  5.0   511000.0
# 13  13.0  8.673333e+05  1.020000e+06  1198.0   76.00  5.0   410000.0
# 14  14.0  1.309000e+06  1.829000e+06  1582.0  126.32  5.0   425000.0
# 15  15.0  1.158333e+06  1.547000e+06  1461.0  108.45  5.0   750000.0
# 16  16.0  5.643667e+06  6.164667e+06  1998.0  189.08  5.0  3250000.0
# 17  17.0  7.946667e+05  1.229667e+06  1248.0   88.50  5.0   650000.0
# 18  18.0  8.153333e+05  1.245333e+06  1248.0   74.00  5.0   627000.0
# 19  19.0  5.130000e+06  6.408000e+06  2143.0  170.00  5.0  1425000.0

# %%
# df.drop(['min_cost_price'], axis=1,inplace=True)
# df.drop(['max_cost_price'], axis=1,inplace=True)
df2.iloc[:,[1,2]]
df['min_cost_price'] = df2.iloc[:,[1]]
df['max_cost_price'] = df2.iloc[:,[2]]

# %%
#how many rows are still nan ?
df.loc[df['max_cost_price'].isnull()]
# Out:
# Empty DataFrame
# Columns: [id, car_name, brand, model, new_price, min_cost_price, max_cost_price, vehicle_age, km_driven, seller_type, fuel_type, transmission_type, mileage, engine, max_power, seats, selling_price]
# Index: []

# %%
#check for false values
comp = list(np.where((df['min_cost_price'] <= df['max_cost_price']) | (df['min_cost_price'].isnull()),True,False))
i=False
if i in comp:
    print("False Values")
    print(comp.count(i))
else:
    print("No False Values")
    
#Check the correlation of all columns with selling price
corr_matrix = df.corr()
print(corr_matrix["selling_price"].sort_values(ascending=False))
# Out:
# No False Values
# selling_price     1.000000
# min_cost_price    0.812779
# max_power         0.750761
# max_cost_price    0.750226
# engine            0.587358
# seats             0.073442
# id                0.024660
# km_driven        -0.103680
# vehicle_age      -0.267211
# mileage          -0.289664
# Name: selling_price, dtype: float64

# %%
# df.loc[(df['min_cost_price'] >= df['max_cost_price'])]

# %%
df.isnull().sum()
# Out:
# id                       0
# car_name                 0
# brand                    0
# model                    0
# new_price            10102
# min_cost_price           0
# max_cost_price           0
# vehicle_age              0
# km_driven                0
# seller_type              0
# fuel_type                0
# transmission_type        0
# mileage                  0
# engine                   0
# max_power                0
# seats                    0
# selling_price            0
# dtype: int64

# %%
df.drop(['new_price'], axis=1,inplace=True)
df.dropna(inplace=True)
df
# Out:
#           id         car_name     brand     model  min_cost_price  \
# 0          0      Maruti Alto    Maruti      Alto    5.160000e+05
# 1          1    Hyundai Grand   Hyundai     Grand    7.110000e+05
# 2          2      Hyundai i20   Hyundai       i20    1.075667e+06
# 3          3      Maruti Alto    Maruti      Alto    4.076667e+05
# 4          4    Ford Ecosport      Ford  Ecosport    1.014000e+06
# ...      ...              ...       ...       ...             ...
# 19539  19539  Toyota Platinum    Toyota  Platinum    9.210000e+05
# 19540  19540    Maruti Ertiga    Maruti    Ertiga    1.624667e+06
# 19541  19541      Skoda Rapid     Skoda     Rapid    6.960000e+05
# 19542  19542  Mahindra XUV500  Mahindra    XUV500    1.783000e+06
# 19543  19543       Honda City     Honda      City    4.265000e+06
#
#        max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 0        6.883333e+05            9     120000  Individual    Petrol
# 1        7.480000e+05            5      20000  Individual    Petrol
# 2        1.412333e+06           11      60000  Individual    Petrol
# 3        5.453333e+05            9      37000  Individual    Petrol
# 4        1.379000e+06            6      30000      Dealer    Diesel
# ...               ...          ...        ...         ...       ...
# 19539    1.413000e+06            4      69480      Dealer    Diesel
# 19540    2.240000e+06            2      18000      Dealer    Petrol
# 19541    1.017333e+06            6      67000      Dealer    Diesel
# 19542    2.491000e+06            5    3800000      Dealer    Diesel
# 19543    4.440333e+06            2      13000      Dealer    Petrol
#
#       transmission_type  mileage  engine  max_power  seats  selling_price
# 0                Manual    19.70     796      46.30      5         120000
# 1                Manual    18.90    1197      82.00      5         550000
# 2                Manual    17.00    1197      80.00      5         215000
# 3                Manual    20.92     998      67.10      5         226000
# 4                Manual    22.77    1498      98.59      5         570000
# ...                 ...      ...     ...        ...    ...            ...
# 19539            Manual    23.59    1364      67.05      5         650000
# 19540            Manual    17.50    1373      91.10      7         925000
# 19541            Manual    21.14    1498     103.52      5         425000
# 19542            Manual    16.00    2179     140.00      7        1225000
# 19543         Automatic    18.00    1497     117.60      5        1200000
#
# [19544 rows x 16 columns]

# %% [markdown]
# # Store the avg of min_cost_price and max_cost_price

# %%
#dictionary for min_cost_price and max_cost_price that we will use in python django at backend
max_dict = {}
min_dict = {}

#function to find mean for each model
def find_mean(car_model):
    brand_df = df.loc[(df['model']== car_model)]
    
    model_max = brand_df['max_cost_price'].mean()
    model_min = brand_df['min_cost_price'].mean()
    
    if(model_max > 0):
        max_dict[car_model] = model_max
        min_dict[car_model] = model_min

    
#find the mean for each brand
for l in model_list:
    find_mean(l)

# %%
print("Total no. of models : ",len(min_dict))
for i in min_dict:
    print(i,"\t"*3, min_dict[i],"\t"*3,max_dict[i])
# Out:
# Total no. of models :  258
# Alto 			 545892.0308483291 			 718872.7506426736
# Grand 			 704114.9425287356 			 823988.5057471265
# i20 			 863086.4606328183 			 1291193.8925680646
# Ecosport 			 1006610.5169340464 			 1388172.9055258466
# S5 			 8182500.0 			 12110000.0
# Ghost 			 79600000.0 			 91100000.0
# Quattroporte 			 20200000.0 			 20900000.0
# SLC 			 11193666.666666666 			 11466666.666666666
# R8 			 7215000.0 			 8337333.333333333
# A-Star 			 830666.6666666666 			 1138666.6666666667
# Corsa 			 863000.0 			 1040666.6666666666
# Qualis 			 863000.0 			 1040666.6666666666
# Winger 			 626166.6666666666 			 817833.3333333333
# Gurkha 			 1000000.0 			 1000000.0

# %% [markdown]
# # Dump df, model_list, min_max

# %%
pickle.dump(df,open('df_handled','wb'))
pickle.dump(model_list,open('model_list','wb'))
pickle.dump(max_dict,open('model_max_dict','wb'))
pickle.dump(min_dict,open('model_min_dict','wb'))

# %% [markdown]
# # Load the files

# %%
df_handled = pickle.load(open('df_handled','rb'))
model_list = pickle.load(open('model_list','rb'))
model_min_dict = pickle.load(open('model_min_dict','rb'))
model_max_dict = pickle.load(open('model_max_dict','rb'))
print(model_list)
print(model_min_dict)
print(model_max_dict)
df_handled
# Out:
# ['Alto' 'Grand' 'i20' 'Ecosport' 'Wagon R' 'i10' 'Venue' 'TUV' 'Indigo'
#  'Captur' 'Swift' 'Micra' 'Verna' 'Duster' 'Cooper' 'Ciaz' 'C-Class'
#  'Innova' 'Baleno' 'Swift Dzire' 'Grande' 'Vento' 'Creta' 'Xylo' 'City'
#  'Bolero' 'Fortuner' 'KWID' 'Amaze' 'Santro' 'XUV500' 'Sail' 'Xcent' '800'
#  'Avigo' 'Nano' 'KUV100' 'Etios' 'Ignis' 'Corolla' 'RediGO' 'Vista' 'Omni'
#  'Scorpio' 'Marazzo' 'Aspire' 'Figo' 'Supro' 'Vitara' 'Tiago' 'Polo'
#  'Seltos' 'Beat' 'Celerio' 'Terrano' 'Santa' 'GO' '5' 'CR-V' 'Endeavour'
#  'KUV' 'Aveo' 'Jazz' 'Pajero' 'Indica' '3' 'Ritz' 'S-Cross' 'Sumo'
#  'Accord' 'Q5' 'A4' 'Tigor' 'Manza' 'Brio' 'SX4' 'Q3' 'Ertiga' 'Safari'
#  'Sunny' 'GLA' 'Thar' 'Hexa' 'Zen' 'Laura' 'Avventura' 'Rover' 'BRV'
#  'Eeco' 'A6' 'E-Class' 'Quanto' 'Q7' 'NuvoSport' 'Z4' 'Koleos' 'A3' '6'
#  'Land Cruiser' 'Scala' 'XF' 'X5' 'Zest' 'CLA' 'Matiz' 'Mulsanne' 'Hector'
#  'EON' 'Ameo' 'Spark' 'GLE' 'Civic' 'Kizashi' 'D-Max' 'Cayenne' 'Fabia'
#  'X1' 'Rapid' 'Freestyle' 'Bolt' 'Superb' 'Captiva' '1' 'Platinum' 'Nexon'
#  'XUV300' 'A' 'Dzire VXI' 'S90' 'S60' 'WR-V' 'XL6' 'Xenon' 'Linea' 'Pulse'
#  'A5' 'Triber' 'CrossPolo' 'Ikon' 'Accent' 'ES' 'Wrangler' 'Camry'
#  'Mobilio' 'Elantra' 'Yaris' 'Lodgy' 'GL-Class' 'Rio' 'Classic' 'Punto'
#  '7' 'S-Presso' 'Yeti' 'Dzire LXI' 'Mustang' 'Aura' 'XC' 'Ghibli' 'Cruze'
#  'Abarth' 'Continental' 'CR' 'Jetta' 'Fiesta' 'Kicks' 'S-Class' 'Sonata'
#  'One' 'Tucson' 'Harrier' 'X3' 'Versa' 'Octavia' 'Ssangyong' 'Enjoy'
#  'Verito' 'Getz' 'Compass' 'CLS' 'XJ' 'redi-GO' 'BR-V' 'B-Class' 'Tavera'
#  'Outlander' 'Beetle' 'M-Class' 'Fluence' 'Glanza' 'Macan' 'X4' 'SLK'
#  'Passat' 'Trailblazer' 'Dzire ZXI' 'Logan' 'B' 'Venture' 'XC90'
#  'Gallardo' 'F-PACE' 'Optra' 'Kodiaq' 'A-Class' 'A8' 'M' 'Clubman' 'MUX'
#  'Tiguan' 'prado' 'Renault' 'X6' 'Palio' 'GTC4Lusso' 'GLS' 'Gypsy'
#  'Lancer' 'V40' 'S4' 'Aria' 'X-Trail' 'Esteem' 'XE' 'Evalia' '1.4Gsi'
#  'XC60' 'Panamera' 'GTI' 'TT' 'MU' 'F-TYPE' 'Montero' 'Sonet' 'F-Pace'
#  'Alturas' 'Boxster' 'Cedia' 'S' 'CLS-Class' 'Altroz' 'NX' 'Carnival'
#  'Prius' 'C' 'CL-Class' 'Avanti' 'RX' 'S5' 'Ghost' 'Quattroporte' 'SLC'
#  'R8' 'A-Star' 'Corsa' 'Qualis' 'Winger' 'Gurkha']
# {'Alto': 545892.0308483291, 'Grand': 704114.9425287356, 'i20': 863086.4606328183, 'Ecosport': 1006610.5169340464, 'Wagon R': 566950.2556950257, 'i10': 648944.7154471545, 'Venue': 962867.8160919539, 'TUV': 1087933.3333333335, 'Indigo': 741632.4786324787, 'Captur': 1662256.4102564098, 'Swift': 719992.7443448569, 'Micra': 785173.4693877551, 'Verna': 1171973.5772357723, 'Duster': 950720.1834862386, 'Cooper': 4653372.549019608, 'Ciaz': 974693.6416184971, 'C-Class': 5031141.242937854, 'Innova': 2039573.0886850157, 'Baleno': 752463.3699633698, 'Swift Dzire': 776585.0187265917, 'Grande': 752247.619047619, 'Vento': 1011350.8771929826, 'Creta': 1267341.2698412698, 'Xylo': 1208075.5555555555, 'City': 1301891.2373403788, 'Bolero': 987080.5687203791, 'Fortuner': 3955279.8573975046, 'KWID': 411328.9760348584, 'Amaze': 790120.626151013, 'Santro': 650000.0, 'XUV500': 1707510.1010101007, 'Sail': 686777.7777777779, 'Xcent': 720798.6798679867, '800': 727166.6666666666, 'Avigo': 591666.6666666666, 'Nano': 718990.4761904762, 'KUV100': 797234.5679012345, 'Etios': 780613.1687242799, 'Ignis': 602173.5159817351, 'Corolla': 1612154.6840958607, 'RediGO': 374542.2222222222, 'Vista': 678745.0980392157, 'Omni': 624071.4285714285, 'Scorpio': 1529619.0476190476, 'Marazzo': 1416250.0, 'Aspire': 887307.6923076923, 'Figo': 825724.4772447724, 'Supro': 644833.3333333333, 'Vitara': 1157111.8644067796, 'Tiago': 610986.2068965518, 'Polo': 764894.5487042002, 'Seltos': 1879345.238095238, 'Beat': 653063.2911392405, 'Celerio': 562931.0829
, 'Spark': 938152.0467836257, 'GLE': 9946013.333333332, 'Civic': 2349090.3954802267, 'Kizashi': 1745500.0, 'D-Max': 2379000.0, 'Cayenne': 11644250.0, 'Fabia': 867552.0833333334, 'X1': 5180339.5061728405, 'Rapid': 1378661.1721611721, 'Freestyle': 989737.3737373737, 'Bolt': 916137.2549019607, 'Superb': 3367250.8960573473, 'Captiva': 1305800.0, '1': 3584866.6666666665, 'Platinum': 1259083.3333333333, 'Nexon': 1469466.6666666667, 'XUV300': 1402333.3333333333, 'A': 954354.1666666666, 'Dzire VXI': 1011764.7058823529, 'S90': 6966750.0, 'S60': 4015564.102564103, 'WR-V': 1253273.9273927393, 'XL6': 1371571.4285714286, 'Xenon': 1091222.2222222222, 'Linea': 912333.3333333335, 'Pulse': 939535.7142857144, 'A5': 8971047.61904762, 'Triber': 875666.6666666666, 'CrossPolo': 1108242.424242424, 'Ikon': 949619.0476190476, 'Accent': 1088523.8095238095, 'ES': 7465000.0, 'Wrangler': 8032000.0, 'Camry': 4450851.851851852, 'Mobilio': 1256157.894736842, 'Elantra': 2530066.666666667, 'Yaris': 17 ...
#           id         car_name     brand     model  min_cost_price  \
# 0          0      Maruti Alto    Maruti      Alto    5.160000e+05
# 1          1    Hyundai Grand   Hyundai     Grand    7.110000e+05
# 2          2      Hyundai i20   Hyundai       i20    1.075667e+06
# 3          3      Maruti Alto    Maruti      Alto    4.076667e+05
# 4          4    Ford Ecosport      Ford  Ecosport    1.014000e+06
# ...      ...              ...       ...       ...             ...
# 19539  19539  Toyota Platinum    Toyota  Platinum    9.210000e+05
# 19540  19540    Maruti Ertiga    Maruti    Ertiga    1.624667e+06
# 19541  19541      Skoda Rapid     Skoda     Rapid    6.960000e+05
# 19542  19542  Mahindra XUV500  Mahindra    XUV500    1.783000e+06
# 19543  19543       Honda City     Honda      City    4.265000e+06
#
#        max_cost_price  vehicle_age  km_driven seller_type fuel_type  \
# 0        6.883333e+05            9     120000  Individual    Petrol
# 1        7.480000e+05            5      20000  Individual    Petrol
# 2        1.412333e+06           11      60000  Individual    Petrol
# 3        5.453333e+05            9      37000  Individual    Petrol
# 4        1.379000e+06            6      30000      Dealer    Diesel
# ...               ...          ...        ...         ...       ...
# 19539    1.413000e+06            4      69480      Dealer    Diesel
# 19540    2.240000e+06            2      18000      Dealer    Petrol
# 19541    1.017333e+06            6      67000      Dealer    Diesel
# 19542    2.491000e+06            5    3800000      Dealer    Diesel
# 19543    4.440333e+06            2      13000      Dealer    Petrol
#
#       transmission_type  mileage  engine  max_power  seats  selling_price
# 0                Manual    19.70     796      46.30      5         120000
# 1                Manual    18.90    1197      82.00      5         550000
# 2                Manual    17.00    1197      80.00      5         215000
# 3                Manual    20.92     998      67.10      5         226000
# 4                Manual    22.77    1498      98.59      5         570000
# ...                 ...      ...     ...        ...    ...            ...
# 19539            Manual    23.59    1364      67.05      5         650000
# 19540            Manual    17.50    1373      91.10      7         925000
# 19541            Manual    21.14    1498     103.52      5         425000
# 19542            Manual    16.00    2179     140.00      7        1225000
# 19543         Automatic    18.00    1497     117.60      5        1200000
#
# [19544 rows x 16 columns]
